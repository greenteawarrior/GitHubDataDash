# %%
import sqlite3
import json
from pprint import pprint

with open('commits.json') as data_file:
    data = json.load(data_file)

# %%
import pandas as pd

# %%
sha = []
name = []
date = []
message = []
html_url = []
repo = []

for commit in data:
    sha.append(commit["sha"])
    # name.append(commit["commit"]["committer"]["name"])
    name.append(commit["author"]["login"])
    date.append(commit["commit"]["committer"]["date"])
    message.append(commit["commit"]["message"])
    html_url.append(commit["html_url"])
    repo.append('/'.join(commit["html_url"].split('/')[3:5]))

pprint([sha, name, date, message, html_url])
# Out:
#   File "<ipython-input-59-64e544b5f13a>", line 15
#     repo.append('/'.join(commit[].split('/')[3:5]))
#                                 ^
# SyntaxError: invalid syntax

# %%
# conn = sqlite3.connect("commits.sqlite")
# c = conn.cursor()

# c.execute("CREATE TABLE GitHubDDash (sha TEXT PRIMARY KEY, name TEXT, date TEXT, message TEXT, html_url TEXT)")
# c.execute("INSERT INTO GitHubDDash ()")

# %%
df = pd.DataFrame({
        "sha": sha,
        "name": name,
        "date": date,
        "message": message,
        "html_url": html_url
    })

# %%
df
# Out:
#                     date                                           html_url  \
# 0   2015-10-27T15:15:43Z  https://github.com/DakotaNelson/robot-street-s...
# 1   2015-10-27T15:14:46Z  https://github.com/DakotaNelson/robot-street-s...
# 2   2015-10-27T15:13:08Z  https://github.com/DakotaNelson/robot-street-s...
# 3   2015-10-27T14:56:41Z  https://github.com/DakotaNelson/robot-street-s...
# 4   2015-10-27T05:26:20Z  https://github.com/DakotaNelson/robot-street-s...
# 5   2015-10-27T05:16:58Z  https://github.com/DakotaNelson/robot-street-s...
# 6   2015-10-27T05:02:20Z  https://github.com/DakotaNelson/robot-street-s...
# 7   2015-10-27T04:58:57Z  https://github.com/DakotaNelson/robot-street-s...
# 8   2015-10-27T04:36:55Z  https://github.com/DakotaNelson/robot-street-s...
# 9   2015-10-27T04:36:45Z  https://github.com/DakotaNelson/robot-street-s...
# 10  2015-10-27T04:36:31Z  https://github.com/DakotaNelson/robot-street-s...
# 11  2015-10-27T04:36:23Z  https://github.com/DakotaNelson/robot-street-s...
# 12  2015-10-27T04:30:46Z  https://github.com/DakotaNelson/robot-street-s...
# 13  2015-10-27T03:54:48Z  https://github.com/DakotaNelson/robot-street-s...
# 14  2015-10-27T03:46:24Z  https://github.com/DakotaNelson/robot-street-s...
# 15  2015-10-27T03:45:11Z  https://github.com/DakotaNelson/robot-street-s...
# 16  2015-10-27T03:38:20Z  https://github.com/DakotaNelson/robot-street-s...
# 17  2015-10-27T03:34:35Z  https://github.com/DakotaNelson/robot-street-s...
# 18  2015-10-27T02:55:52Z  https://github.com/DakotaNelson/robot-street-s...
# 19  2015-10-27T02:06:32Z  https://github.com/DakotaNelson/robot-street-s...
# 20  2015-10-27T01:58:46Z  https://github.com/DakotaNelson/robot-street-s...
# 21  2015-10-27T01:18:24Z  https://github.com/DakotaNelson/robot-street-s...
# 22  2015-10-27T00:52:48Z  https://github.com/DakotaNelson/robot-street-s...
# 23  2015-10-27T00:28:59Z  https://github.com/DakotaNelson/robot-street-s...
# 24  2015-10-26T03:33:32Z  https://github.com/DakotaNelson/robot-street-s...
# 25  2015-10-25T21:42:16Z  https://github.com/DakotaNelson/robot-street-s...
# 26  2015-10-24T20:24:25Z  https://github.com/DakotaNelson/robot-street-s...
# 27  2015-10-24T18:35:16Z  https://github.com/DakotaNelson/robot-street-s...
# 28  2015-10-24T18:05:18Z  https://github.com/DakotaNelson/robot-street-s...
# 29  2015-10-24T17:44:46Z  https://github.com/DakotaNelson/robot-street-s...
#
#                                               message       name  \
# 0   Merge pull request #11 from DakotaNelson/write...  youralien
# 1                              added lessons from Kai  youralien
# 2                               added Lessons section  youralien
# 3   stylized references to code like so: ```StateM...  youralien
# 4                               add youtube demo link  youralien
# 5   Merge branch 'master' of github.com:DakotaNels...  youralien
# 6   Merge pull request #10 from DakotaNelson/syste...  youralien
# 7   added system description of left/right/uturn r...  youralien
# 8   Merge pull request #6 from DakotaNelson/writeu...  youralien
# 9   Merge pull request #7 from DakotaNelson/writeu...  youralien
# 10  Merge pull request #8 from DakotaNelson/writeu...  youralien
# 11  Merge pull request #9 from DakotaNelson/writeu...  youralien
# 12                           Add code structure blurb    kailevy
# 13                               Add challenges blurb    kailevy
# 14    add detecting signs in images + intro to system  youralien
# 15                             Add improvements blurb    kailevy
# 16                           Remove unnecessary files    kailevy
# 17                                   Add design blurb    kailevy
# 18                        add system overview diagram  youralien
# 19                   added writeup template to readme  youralien
# 20  Merge pull request #5 from DakotaNelson/integr...  youralien
# 21                        commented sign_following.py  youralien
# 22  cleaned unused code and added comments for str...  youralien
# 23          refactor and document template_matcher.py  youralien
# 24                       Integrate a working version!    kailevy
# 25      add intercommunication, with imSleeping topic  youralien
# 26                  error handling for bbox not found  youralien
# 27      fixed rostopic naming inconsistencies => mvp!  youralien
# 28                              Use new normalization    kailevy
# 29  Merge branch 'master' of https://github.com/Da...    kailevy
#
#                                          sha
# 0   7bb194fd527242c7b50c4d6ee30102b9c1376883
# 1   a1faec7f29e0b18b6766df58531bc47628618c7e
# 2   8dfdf3dbf2fe6ff5a4f7320c992c46e9b1764408
# 3   65cc99650b226b3332edddc79416aa5f96e8432a
# 4   7c96fb339f4fd3bf2de6a8a5f89def4238af7f30
# 5   d5daee8a0667d294c545d5865670c832d7ac0921
# 6   eb388c97c4b13e8db0ea55c89d7ae3165c2887d2
# 7   2ff8286d3133243d1d5c680da5f31c4479004766
# 8   758261058a6a0c95d3a8b0d72bfa94be25cf37fe
# 9   fba755b98e305d853de39dad14c322b1547b85ca
# 10  45d5614da368eaa50274b053c65118c6ac80c385
# 11  88440b1e7a26368cd5cf7670ccb6e00c7fb2354c
# 12  30af84ecef2a02abbb350a617a2c502d2a49d7ed
# 13  e485a678955cd21464ffee57b16fa6962288ceb7
# 14  c83f6f522575c662fb52d226c2c55cc4fb7c8808
# 15  b8fcb4ce106b6b38efb1e9b3627195a2191e8010
# 16  7cfeee36146922bd021cd3a5c1c06f0bfd6d40cc
# 17  7b21cbdc3d4826978e20d42d9c54db4a7b57462b
# 18  eeaaca068349f089fa9f40f40dd0853562349a6a
# 19  3d305b04a2667791657c8019f6c4288361f333d9
# 20  ca2f40afa7a5943233856239ce271f7561b8f51d
# 21  c7863f3fdd5bf65196a59f83f64429c1162ac3de
# 22  3f29c0fbd1841a409b51fab2c96c3fe45e693637
# 23  6fd958e561e93a1e334e6455b899386c4f1e41e6
# 24  ec8999b21f9554131674c6eaead4dd8bcf120f72
# 25  ecaf1633abe2719f31b5f23b04246148bbadd76c
# 26  52b58b82213c688df4125393f55a0a0a3a28ae1f
# 27  09100342e200094284a135873a7f0413d06ac4b5
# 28  3818f7a691ff825d8d546b9ee88a1759fb32d8a3
# 29  123141613dcf8b68d495cfb8d4063664170d367e
